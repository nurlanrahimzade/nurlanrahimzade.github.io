# %%
import pandas as pd

# %%
data = pd.read_excel('Furniture sales.xls')

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520  \
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...
# 0      Claire Gute   Consumer  United States        Henderson  ...  \
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category
# ...

# %%
#To find the total sales and profit

total_sales = data['Sales'].sum()
total_profit = data['Profit'].sum()

# %%
#To identify the top-selling products

top_products = data['Product Name'].value_counts().head(10)

# %%
total_sales = data['Sales'].sum()
total_profit = data['Profit'].sum()

# %%
#To identify the top-selling products

top_products = data['Product Name'].value_counts().head(10)
print(top_products)
# Out:
# Product Name
# Staple envelope                                              48
# Staples                                                      46
# Easy-staple paper                                            46
# Avery Non-Stick Binders                                      20
# Staples in misc. colors                                      19
# Staple remover                                               18
# KI Adjustable-Height Table                                   18
# Storex Dura Pro Binders                                      17
# Staple-based wall hangings                                   16
# Logitech 910-002974 M325 Wireless Mouse for Web Scrolling    15
# Name: count, dtype: int64

# %%
#Explore Sales Performance Over Time
data['Order Date'] = pd.to_datetime(data['Order Date'])
data['YearMonth'] = data['Order Date'].dt.to_period('M')
monthly_sales = data.groupby('YearMonth')['Sales'].sum()
print(monthly_sales)
# Out:
# YearMonth
# 2014-01     14236.8950
# 2014-02      4519.8920
# 2014-03     55691.0090
# 2014-04     28295.3450
# 2014-05     23648.2870
# 2014-06     34595.1276
# 2014-07     33946.3930
# 2014-08     27909.4685
# 2014-09     81777.3508
# 2014-10     31453.3930
# 2014-11     78628.7167
# 2014-12     69545.6205
# 2015-01     18174.0756
# 2015-02     11951.4110
# 2015-03     38726.2520
# 2015-04     34195.2085
# 2015-05     30131.6865
# 2015-06     24797.2920
# 2015-07     28765.3250
# 2015-08     36898.3322
# 2015-09     64595.9180
# 2015-10     31404.9235
# 2015-11     75972.5635
# 2015-12     74919.5212
# 2016-01     18542.4910
# 2016-02     22978.8150
# 2016-03     51715.8750
# 2016-04     38750.0390
# 2016-05     56987.7280
# 2016-06     40344.5340
# 2016-07     39261.9630
# 2016-08     31115.3743
# 2016-09     73410.0249
# 2016-10     59687.7450
# 2016-11     79411.9658
# 2016-12     96999.0430
# 2017-01     43971.3740
# 2017-02     20301.1334
# 2017-03     58872.3528
# ...

# %%
#Perform Profitability Analysis:
#For example, to calculate the average profit and profit margin

average_profit = data['Profit'].mean()
profit_margin = (data['Profit'].sum() / data['Sales'].sum()) * 100
print("Average Profit:", average_profit)
print("Profit Margin (%):", profit_margin)
# Out:
# Average Profit: 28.656896307784663
# Profit Margin (%): 12.4672172403156

# %%
#To perform customer analysis,

top_customers = data.groupby('Customer ID')['Sales'].sum().sort_values(ascending=False).head(10)
print(top_customers)


#This code groups the data by 'Customer ID', calculates the total sales for each customer, sorts them in descending order, and displays the top 10 customers.
# Out:
# Customer ID
# SM-20320    25043.050
# TC-20980    19052.218
# RB-19360    15117.339
# TA-21385    14595.620
# AB-10105    14473.571
# KL-16645    14175.229
# SC-20095    14142.334
# HL-15040    12873.298
# SE-20110    12209.438
# CC-12370    12129.072
# Name: Sales, dtype: float64

# %%
#Geographic Analysis:

#This code groups the data by 'Region' and calculates the total sales for each region.

sales_by_region = data.groupby('Region')['Sales'].sum()
print(sales_by_region)
# Out:
# Region
# Central    501239.8908
# East       678781.2400
# South      391721.9050
# West       725457.8245
# Name: Sales, dtype: float64

# %%
#Order and Delivery Analysis:
#This code counts the occurrences of each shipping mode in the dataset

shipping_modes = data['Ship Mode'].value_counts()
print(shipping_modes)
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %% [markdown]
# # Sales Trend Analysis:
# #To analyze sales trends over time, we can visualize the monthly sales figures using a line plot.

# %%
#convert the 'Order Date' column to the 'datetime64' data type:
data['Order Date'] = pd.to_datetime(data['Order Date'])

# %%
#After converting the column to the correct data type, 
# we can proceed with the calculation of the monthly sales trend

# %%
# Convert 'Order Date' column to datetime format
data['Order Date'] = pd.to_datetime(data['Order Date'])

# Extract year and month from the 'Order Date' column
data['YearMonth'] = data['Order Date'].dt.to_period('M')

# Group data by 'YearMonth' and calculate monthly sales
monthly_sales = data.groupby('YearMonth')['Sales'].sum()

# Convert 'YearMonth' to string format for plotting
monthly_sales.index = monthly_sales.index.astype(str)

# Plot the sales trend
plt.figure(figsize=(10, 6))
plt.plot(monthly_sales.index, monthly_sales.values, marker='o')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.title('Monthly Sales Trend')
plt.xticks(rotation=45)
plt.show()

# %%
# Calculate total sales by region
# Analyzing the sales by region:
# Calculate the total sales for each region.
# Visualize the sales by region using a bar chart.



sales_by_region = data.groupby('Region')['Sales'].sum()

# Visualize sales by region
plt.figure(figsize=(10, 6))
sales_by_region.plot(kind='bar', color='blue')
plt.xlabel('Region')
plt.ylabel('Sales')
plt.title('Sales by Region')
plt.xticks(rotation=0)
plt.show()

# %%
# Analyzing the sales by category and sub-category:
# Calculate the total sales for each category and sub-category.
# Visualize the sales by category and sub-category using a bar chart.

# Calculate total sales by category and sub-category
sales_by_category = data.groupby(['Category', 'Sub-Category'])['Sales'].sum().unstack()

# Visualize sales by category and sub-category
plt.figure(figsize=(12, 6))
sales_by_category.plot(kind='bar')
plt.xlabel('Category')
plt.ylabel('Sales')
plt.title('Sales by Category and Sub-Category')
plt.xticks(rotation=45)
plt.legend(title='Sub-Category')
plt.show()

# %%
# Calculate total sales by category and sub-category
# We shift subcategory list to right handside of graph


sales_by_category = data.groupby(['Category', 'Sub-Category'])['Sales'].sum().unstack()

# Visualize sales by category and sub-category
plt.figure(figsize=(12, 6))
sales_by_category.plot(kind='bar')
plt.xlabel('Category')
plt.ylabel('Sales')
plt.title('Sales by Category and Sub-Category')
plt.xticks(rotation=45)
plt.legend(title='Sub-Category', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

# %% [markdown]
# # Analyzing the profitability:
# Calculate the total profit for each category and sub-category.
# Visualize the profitability by category and sub-category using a bar chart.

# %%
# Calculate total profit by category and sub-category
profit_by_category = data.groupby(['Category', 'Sub-Category'])['Profit'].sum().unstack()

# Visualize profitability by category and sub-category
plt.figure(figsize=(12, 6))
profit_by_category.plot(kind='bar')
plt.xlabel('Category')
plt.ylabel('Profit')
plt.title('Profitability by Category and Sub-Category')
plt.xticks(rotation=45)
plt.legend(title='Sub-Category', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

# %% [markdown]
# # Analyzing the top-selling products:
# Identify the top-selling products based on the quantity sold.
# Visualize the top-selling products using a horizontal bar chart.

# %%
# Identify the top-selling products based on quantity sold
top_products = data.groupby('Product Name')['Quantity'].sum().nlargest(10)

# Visualize the top-selling products
plt.figure(figsize=(10, 6))
top_products.sort_values().plot(kind='barh')
plt.xlabel('Quantity Sold')
plt.ylabel('Product Name')
plt.title('Top-selling Products')
plt.show()

# %% [markdown]
# # Analyzing the customer segments:
# Calculate the count of customers for each segment.
# Visualize the customer segments using a pie chart.

# %%
# Calculate the count of customers for each segment
customer_segments = data['Segment'].value_counts()

# Visualize the customer segments
plt.figure(figsize=(8, 6))
customer_segments.plot(kind='pie', autopct='%1.1f%%')
plt.title('Customer Segments')
plt.ylabel('')
plt.show()

# %% [markdown]
# # Analyzing the shipping modes:
# Calculate the count of orders for each shipping mode.
# Visualize the shipping modes using a pie chart.

# %%
# Import the necessary libraries
import seaborn as sns

# Select the numerical columns for correlation analysis
numerical_columns = ['Sales', 'Quantity', 'Discount', 'Profit']
numerical_data = data[numerical_columns]

# Calculate the correlation matrix
correlation_matrix = numerical_data.corr()

# Visualize the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# to display the correlation values in number format
# Calculate the correlation matrix


correlation_matrix = numerical_data.corr()

# Display the correlation matrix as numbers
print(correlation_matrix)
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %%
#Let's continue with the analysis by examining the sales performance across different regions and visualizing the results

# Group data by region and calculate total sales
region_sales = data.groupby('Region')['Sales'].sum().sort_values(ascending=False)

# Plotting the sales by region
plt.figure(figsize=(10, 6))
sns.barplot(x=region_sales.index, y=region_sales.values)
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.title('Total Sales by Region')
plt.show()

# %%
#profitability of different product categories.

# Group data by category and calculate average profit
category_profit = data.groupby('Category')['Profit'].mean().sort_values(ascending=False)

# Plotting the average profit by category
plt.figure(figsize=(10, 6))
sns.barplot(x=category_profit.index, y=category_profit.values)
plt.xlabel('Category')
plt.ylabel('Average Profit')
plt.title('Average Profit by Category')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Sales and profitability trends over time.

# %%
# Convert the Order Date column to datetime
data['Order Date'] = pd.to_datetime(data['Order Date'])

# Extract the year and month from the Order Date
data['YearMonth'] = data['Order Date'].dt.to_period('M').astype(str)

# Calculate the monthly sales and profit
monthly_sales = data.groupby('YearMonth')['Sales'].sum()
monthly_profit = data.groupby('YearMonth')['Profit'].sum()

# Plotting the sales trend
plt.figure(figsize=(12, 6))
plt.plot(monthly_sales.index, monthly_sales.values, marker='o')
plt.xlabel('Year-Month')
plt.ylabel('Sales')
plt.title('Monthly Sales Trend')
plt.xticks(rotation=45)
plt.show()

# Plotting the profit trend
plt.figure(figsize=(12, 6))
plt.plot(monthly_profit.index, monthly_profit.values, marker='o', color='green')
plt.xlabel('Year-Month')
plt.ylabel('Profit')
plt.title('Monthly Profit Trend')
plt.xticks(rotation=45)
plt.show()

# %%
#Top products in terms of sales

# Group data by product name and calculate total sales
product_sales = data.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)

# Plotting the top products by sales
plt.figure(figsize=(12, 6))
sns.barplot(x=product_sales.values, y=product_sales.index, orient='h')
plt.xlabel('Sales')
plt.ylabel('Product Name')
plt.title('Top Products by Sales')
plt.show()
